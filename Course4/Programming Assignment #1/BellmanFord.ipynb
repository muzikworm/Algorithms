# %%
INT_MAX = 100000000000
def bellmanford(graph,src):
    dist = [INT_MAX]*(v+1)
    dist[src] = 0

    for i in range(v):
        for t, h, w in graph:
            #print(t,h,w)
            if dist[t] != INT_MAX and dist[t] + w < dist[h]:
                    dist[h] = dist[t] + w

    for t, h, w in graph:
            if dist[t] != INT_MAX and dist[t] + w < dist[h]:
                    return 0
                         

    return (dist)

# %%
#g1
graph1=[]
with open('g1.txt') as f:
    v,e = [int(x) for x in f.readline().split()]
    for x in f:
        t,h,w = [int(y) for y in x.split()]
        #print(t,h,w)
        graph1.append([t,h,w])

# %%
for i in range(1,v+1):
    if bellmanford(graph1,i) == 0:
        print('g1 has a negative cycle')
        break
    else:
        if m > min(x):
            m = min(x)
# Out:
# g1 has a negative cycle

# %%
#g2
graph2=[]
with open('g2.txt') as f:
    v,e = [int(x) for x in f.readline().split()]
    for x in f:
        t,h,w = [int(y) for y in x.split()]
        #print(t,h,w)
        graph2.append([t,h,w])

# %%
for i in range(1,v+1):
    if bellmanford(graph2,i) == 0:
        print('g2 has a negative cycle')
        break
    else:
        if m > min(x):
            m = min(x)
# Out:
# g2 has a negative cycle

# %%
#g3
graph3=[]
with open('g3.txt') as f:
    v,e = [int(x) for x in f.readline().split()]
    for x in f:
        t,h,w = [int(y) for y in x.split()]
        #print(t,h,w)
        graph3.append([t,h,w])

# %%
m = INT_MAX
for i in range(1,v+1):
    if(i%10 == 0):
        print(i)
        print(m)
    x= bellmanford(graph3,i)
    if x == 0:
        print('g3 has a negative cycle')
        break
    else:
        if m > min(x):
            m = min(x)
# Out:
# 10
# -17
# 20
# -18
# 30
# -18
# 40
# -18
# 50
# -18
# 60
# -18
# 70
# -18
# 80
# -18
# 90
# -18
# 100
# -18
# 110
# -18
# 120
# -18
# 130
# -18
# 140
# -18
# 150
# -18
# 160
# -18
# 170
# -18
# 180
# -18
# 190
# -18
# 200
# -18
# 210
# -18
# 220
# -18
# 230
# -18
# 240
# -18
# 250
# -18
# 260
# -18
# 270
# -18
# 280
# -18
# 290
# -18
# 300
# -18
# 310
# -18
# 320
# -18
# 330
# -18
# 340
# -18
# 350
# -18
# 360
# -18
# 370
# -18
# 380
# -18
# 390
# -18
# 400
# -19
# 410
# -19
# 420
# -19
# 430
# -19
# 440
# -19
# 450
# -19
# 460
# -19
# 470
# -19
# 480
# -19
# 490
# -19
# 500
# -19
# 510
# -19
# 520
# -19
# 530
# -19
# 540
# -19
# 550
# -19
# 560
# -19
# 570
# -19
# 580
# -19
# 590
# -19
# 600
# -19
# 610
# -19
# 620
# -19
# 630
# -19
# 640
# -19
# 650
# -19
# 660
# -19
# 670
# -19
# 680
# -19
# 690
# -19
# 700
# -19
# 710
# -19
# 720
# -19
# 730
# -19
# 740
# -19
# 750
# -19
# 760
# -19
# 770
# -19
# 780
# -19
# 790
# -19
# 800
# -19
# 810
# -19
# 820
# -19
# 830
# -19
# 840
# -19
# ...
